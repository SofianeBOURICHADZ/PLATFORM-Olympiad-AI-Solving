# %%
import numpy as np
import pandas as pd

np.random.seed(0)

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %% [markdown]
# SUBTASK1  and   SUBTASK2

# %%
subtask1_df = test_data[(test_data['liceu'] == 'COLEGIUL NATIONAL "UNIREA" FOCSANI') & (test_data['materie'] != 'GENERAL') & (test_data['materie'] != 'LIMBA ROMANA')]
subtask1_answer = subtask1_df['materie'].iloc[np.argmax(subtask1_df['preferinta_materie'].values)]

subtask2_df = train_data[(train_data['liceu'] == 'COLEGIUL NATIONAL "UNIREA" FOCSANI') & (train_data['materie'] == 'INFORMATICA MI C-C++')]
subtask2_answer = subtask2_df['an'].iloc[np.argmax(subtask2_df['preferinta_materie'].values)]

# %% [markdown]
# SUBTASK3

# %% [markdown]
# SUBMISSION

# %%
df1 = pd.DataFrame({
    'id':[1,2],
    'subtaskID':[1,2],
    'answer':[subtask1_answer,subtask2_answer]
})
